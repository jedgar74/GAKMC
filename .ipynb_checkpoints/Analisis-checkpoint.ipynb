# %%
from Analisis import *
b = Analisis()
b.run()
# Out:
# -------analisis---------
# ----------------  2020-10-26 00:00:00 2020-11-01 00:00:00
# ------ Forecast ------
# ------ Forecast ------  ('', 0)
# ------ Forecast ------  ('Compacto', 1)
# ------ Forecast ------  ('Compacto SUV', 13)
# ------ Forecast ------  ('Fullsize SUV', 2)
# ------ Forecast ------  ('Intermedio', 6)
# ------ Forecast ------  ('Panel VAN', 1)
# ------ Forecast ------  ('PickUp', 11)
# ------ Forecast ------  ('SUV', 15)
# ------ Forecast ------  ('VAN', 1)
# -------- Data -------
# -------- Data -------  ('PickUp', 8, 3, 1.714)
# -------- Data -------  ('Intermedio', 2, 3, 1.857)
# -------- Data -------  ('SUV', 14, 3, 1.286)
# -------- Data -------  ('Compacto', 0, 0, 0.0)
# -------- Data -------  ('Fullsize SUV', 0, 1, 1.0)
# -------- Data -------  ('Compacto SUV', 7, 4, 2.857)
# -------- Data -------  ('Panel VAN', 0, 0, 0.0)
# -------- Data -------  ('', 0, 0, 0.0)
# -------- Data -------  ('VAN', 0, 0, 0.0)
#
# ---- Errores  / Mejora ----  1  /  7.0
#
# ...
